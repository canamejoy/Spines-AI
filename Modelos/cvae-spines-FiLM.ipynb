# %%
# !pip install scikit-learn==1.5.0
# !pip install optuna
# Out:
# Collecting scikit-learn==1.5.0
#   Downloading scikit_learn-1.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.5.0) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.5.0) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.5.0) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.5.0) (3.6.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.19.5->scikit-learn==1.5.0) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.19.5->scikit-learn==1.5.0) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.19.5->scikit-learn==1.5.0) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.19.5->scikit-learn==1.5.0) (2025.3.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.19.5->scikit-learn==1.5.0) (2022.3.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.19.5->scikit-learn==1.5.0) (2.4.1)
# Requirement already satisfied: onemkl-license==2025.3.0 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.19.5->scikit-learn==1.5.0) (2025.3.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.19.5->scikit-learn==1.5.0) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.19.5->scikit-learn==1.5.0) (2022.3.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.19.5->scikit-learn==1.5.0) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.19.5->scikit-learn==1.5.0) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.19.5->scikit-learn==1.5.0) (2024.2.0)
# Downloading scikit_learn-1.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 18.4 MB/s eta 0:00:00
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.5.0 which is incompatible.
# Successfully installed scikit-learn-1.5.0
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (4.5.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (1.17.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna) (6.10.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.41)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.3)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->optuna) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->optuna) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->optuna) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->optuna) (2025.3.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->optuna) (2022.3.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->optuna) (2.4.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.11/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.3)
# Requirement already satisfied: onemkl-license==2025.3.0 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->optuna) (2025.3.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->optuna) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->optuna) (2022.3.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->optuna) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->optuna) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->optuna) (2024.2.0)

# %%
import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import transforms as T
import torch.utils.data as data_utils
from torch.utils.data import TensorDataset, random_split, DataLoader
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
import optuna
import optuna.visualization as vis
import cupy as cp
from cuml.manifold import UMAP as cumlUMAP

# %% [markdown]
# crear device para pytorch

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# Descargar el dataset

# %%
data_set = np.load('/kaggle/input/kdm-database-spiners/data.npy.npz')
print(data_set.files)
# Out:
# ['Nest', 'L', 'rd', 'So', 'T', 'Jex', 'Jex2', 'Jex3', 'Jex4', 'Kan1', 'KanS', 'Hex', 'kd', 'KDM', 'MS']

# %% [markdown]
# En "data" se cargan las imagenes de las configuraciones de los espines, se reorganiza para que quede de la forma (N, C, H, W). Se redimensiona de 39x39 a 40x40 para que el cambio de dimensionalidad sea simetrico en el encoder y el decoder

# %%
data = data_set['MS']
data.shape
data = torch.from_numpy(data).permute(0, 3, 1, 2).float()
data = F.interpolate(data, size=(40, 40), mode='bilinear')
data = data / data.max() #normalizar, queda [-1,1]
data = (data + 1) / 2 #mover rango [0,1]
data.shape
# Out:
# torch.Size([164212, 1, 40, 40])

# %% [markdown]
# Como este es un cvae, "y" va a ser el vector con los parámetros que van a condicionar el modelo

# %%
kdm = data_set['KDM']
t = data_set['T']
y = np.column_stack((kdm, t))
y = torch.from_numpy(y).float()
y.shape
# Out:
# torch.Size([164212, 2])

# %%
full_dataset = TensorDataset(data, y)

val_size = int(len(full_dataset) * 0.2)
train_size = len(full_dataset) - val_size
train_dataset, val_dataset = random_split(full_dataset, [train_size, val_size])

# %%
train_loader = data_utils.DataLoader(
    train_dataset, 
    batch_size=128, 
    shuffle=True
)

val_loader = DataLoader(
    val_dataset,
    batch_size=128, 
    shuffle=False
)

# %% [markdown]
# #### La arquitectura de este CVAE cuenta:
# Este, al ser un CVAE (FiLM), cuenta con la siguiente estructura:
# En este modelo, el VAE se condicionó de la siguiente manera:
# - Se pasaron los parámetros (kdm y t) por redes densas y se generan dos parámetros $\gamma$(factor de escala) y $\beta$ (factor de balance). Cuando los datos pasan por el encoder, pasan de $x$ a $h$, entonces, los parámetros $\gamma$ y $\beta$ modulan este vector $h$. Así mismo funciona para el decoder.
# - Se condicionó el prior, es decir, se pasó de $p(z)$ a $p(z|y)$
#
# Donde $y$ es el vector que contiene a los parámetros kdm y t.
#
# Así, de la distribución marginal aproximada por el encoder $q(x|y)$ resulta $\mu_q$ y $\log{\sigma_q}$
#
# Y de la distribución prior $p(z|y)$ resulta $\mu_p$ y $\log{\sigma_p}$
#
# Para el encoder: se deja la función build_encoder para que durante la optimización pruebe diferentes configuraciones de capas, un flaten despues del ciclo para aplanar los datos. Se añadieron capas para calcular gamma y beta y son estas quienes ingresan a la capa que genera mu_q y logvar_q.
#
# Para el dencoder: se separa la primera capa para aplicar ahí los parámetros gamma y beta, el encoder en este caso empieza desde la capa de unflatten y se construyen las demás capas conv.
#
# Además, se define una función flat_dim para calcular el tamaño que tiene el tensor después de cada capa convolucional. Lo que se hace es pasar un tensor de ceros con el mismo tamaño de la imagen original a través del encoder para así saber el tamaño después de cada capa. De esta manera se calcula el out padding para no tener problemas con la reconstrucción y que $\hat{x}$ sea de la misma dimensión que $x$

# %%
class CVAE(nn.Module):
    def __init__(self, z_dim, layers_config, device, cond_dim=2):
        super(CVAE, self).__init__()
        self.z_dim = z_dim
        self.layers_config = layers_config
        self.kernel_size = 4
        self.stride = 2
        self.padding = 1
        self.cond_dim = cond_dim
        self.device = device  

        self.cond = nn.Sequential(
            nn.Linear(self.cond_dim, 64),
            nn.LeakyReLU(0.2),
            nn.Linear(64, 128),
            nn.LeakyReLU(0.2)
        ).to(self.device)
        
        self.cond_dim_process = 128

        self.encoder = self._build_encoder(layers_config).to(self.device)
        self.flat_dim, self.h_start, self.w_start = self._infer_start_dim()
        
        # generadores FiLM para modular la salida aplanada del encoder
        self.film_gen_q_gamma = nn.Linear(self.cond_dim_process, self.flat_dim).to(self.device)
        self.film_gen_q_beta = nn.Linear(self.cond_dim_process, self.flat_dim).to(self.device)

        # Las capas 'q' ahora solo reciben 'flat_dim', no la dimensión concatenada
        self.fc_mu_q = nn.Linear(self.flat_dim, z_dim).to(self.device)
        self.fc_logvar_q = nn.Linear(self.flat_dim, z_dim).to(self.device)

        # generadores FiLM para modular z
        self.film_gen_dec_gamma = nn.Linear(self.cond_dim_process, self.z_dim).to(self.device)
        self.film_gen_dec_beta = nn.Linear(self.cond_dim_process, self.z_dim).to(self.device)

        # se separa las capas conv de la densa
        # La capa densa ahora solo toma 'z_dim', no la dimensión concatenada
        self.decoder_fc = nn.Linear(self.z_dim, self.flat_dim).to(self.device)
        # La parte convolucional se construye con una nueva función auxiliar
        self.decoder_convs = self._build_decoder_convs().to(self.device)

        self.fc_mu_p = nn.Linear(self.cond_dim_process, z_dim).to(self.device)
        self.fc_logvar_p = nn.Linear(self.cond_dim_process, z_dim).to(self.device)
        
    def _build_encoder(self, layers_config):
        layers = []
        in_ch = 1
        for (n_filters, use_bn) in layers_config:
            layers.append(nn.Conv2d(in_ch, n_filters, kernel_size=3, stride=2, padding=1))
            if use_bn:
                layers.append(nn.BatchNorm2d(n_filters))
            layers.append(nn.LeakyReLU(0.2, inplace=True))
            in_ch = n_filters
        layers.append(nn.Flatten())
        encoder = nn.Sequential(*layers)
        return encoder

    def _infer_start_dim(self):
        x = torch.zeros(1, 1, 40, 40).to(self.device)
        with torch.no_grad():
            temp_encoder = nn.Sequential(*list(self.encoder.children())[:-1]) 
            temp_encoder.eval()            
            current_layer = x
            for layer in temp_encoder:
                current_layer = layer(current_layer)
            out = current_layer
        flat_dim = out.shape[1] * out.shape[2] * out.shape[3]
        h_start, w_start = out.shape[2], out.shape[3] 
        return flat_dim, h_start, w_start

    # construir solo la parte convolucional del decoder
    def _build_decoder_convs(self):
        layers = []
        layers.append(nn.Unflatten(1, (self.layers_config[-1][0], self.h_start, self.w_start)))
        layers.append(nn.LeakyReLU(0.2, inplace=True))
        
        reversed_config = list(reversed(self.layers_config))
        N_layers = len(reversed_config)
        in_ch = reversed_config[0][0] 
        
        for i in range(N_layers): 
            is_final_layer = (i == N_layers - 1)
            out_ch = 1 if is_final_layer else reversed_config[i+1][0] 
            use_bn = reversed_config[i+1][1] if not is_final_layer else False
            
            layers.append(nn.ConvTranspose2d(in_ch, out_ch, kernel_size=4, stride=2, padding=1))
            in_ch = out_ch
            
            if not is_final_layer:
                if use_bn:
                    layers.append(nn.BatchNorm2d(out_ch))
                layers.append(nn.LeakyReLU(0.2, inplace=True))
            else:
                layers.append(nn.Sigmoid())
                
        decoder_convs = nn.Sequential(*layers)
        return decoder_convs
    
    def encode(self, x, y):
        h = self.encoder(x)
        y_process = self.cond(y)
        gamma_q = torch.tanh(self.film_gen_q_gamma(y_process))
        beta_q = self.film_gen_q_beta(y_process)
        h_filmed = (gamma_q + 1) * h + beta_q
        
        mu_q = self.fc_mu_q(h_filmed)
        logvar_q = self.fc_logvar_q(h_filmed)
        return mu_q, logvar_q

    def get_prior(self, y):
        y_process = self.cond(y)
        mu_p = self.fc_mu_p(y_process)
        logvar_p = self.fc_logvar_p(y_process)
        return mu_p, logvar_p

    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        z = mu + eps*std
        return z

    def decode(self, z, y):
        y_process = self.cond(y)
        gamma_dec = torch.tanh(self.film_gen_dec_gamma(y_process))
        beta_dec = self.film_gen_dec_beta(y_process)
        z_filmed = (gamma_dec + 1) * z + beta_dec
        
        h_dec = self.decoder_fc(z_filmed)
        return self.decoder_convs(h_dec)

    def forward(self, x, y):
        mu_q, logvar_q = self.encode(x, y)
        z = self.reparameterize(mu_q, logvar_q)
        x_hat = self.decode(z, y)
        mu_p, logvar_p = self.get_prior(y)
        return x_hat, mu_q, logvar_q, mu_p, logvar_p

    def get_intermediate_features(self, x):
        features = {}
        h = x
        conv_blocks = list(self.encoder.children())
        
        h = conv_blocks[0](h)
        features['L1'] = h.flatten(start_dim=1) 
        
        h = conv_blocks[1](h)
        features['L2'] = h.flatten(start_dim=1)
    
        h = conv_blocks[2](h)
        features['L3'] = h.flatten(start_dim=1)
        
        return features

# %% [markdown]
# La función de pérdida está dada por:
#
#
# $$
# L_{\text{loss}} = \frac{1}{N} \sum_{k=1}^{N} \left[ L_{\text{MSE}}(x_k, \hat{x}_k) + \beta \cdot D _{KL}(q_k || p) \right]
# $$
# $$
# L_{loss} = \frac{1}{N} \sum_{k=1}^{N} \left( \frac{1}{D} \sum_{i=1}^{D} \left( x_{k,i} - \hat{x}_{k,i} \right) ^2 \right)  +  \beta \cdot \sum _{k=1}^{N} \left( \sum _{j=1}^{Z}{(-0.5(1 + \log (\sigma^2 _{k,j}) - \mu^2 _{k,j} - \sigma ^2 _{k,j})}) \right)
# $$
# Donde, $$N= \text{tamaño del batch, } D= \text{numero de pixeles (1 * 40 * 40), } Z = \text{dimension de z, } \beta = \text{peso de la KLD}$$

# %%
def loss_function(x_hat, x, mu_q, logvar_q, mu_p, logvar_p, beta):
    MSE = F.mse_loss(x_hat, x, reduction='sum')
    var_q = torch.exp(logvar_q)
    var_p = torch.exp(logvar_p)
    epsilon = 1e-8
    KLD = 0.5 * torch.sum(logvar_p - logvar_q + (var_q + (mu_q - mu_p).pow(2)) / (var_p + epsilon) - 1)
    loss = (MSE + beta * KLD) / x.size(0)
    return loss, MSE, KLD

# %% [markdown]
# A diferencia del anterior cuadernillo, se va aplicar bayes optimización (con la librería optuna) para encontrar los mejores hiperparametros para esta red. En este caso se quiere optimizar:
# - lr: learning rate
# - z_dim: dimensión del espacio latente
# - beta: importancia que se le da a la kl divergence
# - batch_size: tamaño del batch sobre el se entrena en cada época
# - optimizer: verificar si es mejor con adam o con descenso de gradiente
# - growth: escalamiento de los filtros en cada capa
# - use_bn: si se usa batch normalization o no después de cada capa
#
# El modelo sustituo utilizado es: TPE (Tree-structured Parzen Estimators)
# $$\text{TPE}_{Acq}(x) \propto \frac{l(x)}{g(x)}$$
# Donde,
# - $l(x) = p(x | y < y^*)$ : La densidad de probabilidad de los hiperparámetros $x$ que dieron buenos resultados (una pérdida $y$ por debajo de un umbral $y^*$)
# - $g(x) = p(x | y \ge y^*)$ : La densidad de probabilidad de los hiperparámetros $x$ que dieron malos resultados
#
# Y la función de adquisición es: EI (Expected Improvement)
# $$EI(x) = \sigma(x) [Z \Phi(Z) + \phi(Z)]$$
# Donde,
# - $y^*$ es el mejor valor (mínimo) de la función objetivo (pérdida) observado hasta ahora.
# - $\mu(x)$ y $\sigma(x)$ son la media y la desviación estándar predichas por el modelo sustituto en el punto $x$
# - $Z = \frac{y^* - \mu(x)}{\sigma(x)}$
# - $\phi(Z)$ es la Función de Densidad de Probabilidad (PDF) de una distribución normal estándar
# - $\Phi(Z)$ es la Función de Distribución Acumulada (CDF) de una distribución normal estándar

# %%
def objective(trial):
    params = {
        'lr': trial.suggest_float('lr', 1e-5, 5e-2, log=True), 
        'z_dim': trial.suggest_int('z_dim', 8, 64),
        'beta': trial.suggest_float('beta', 0.1, 10.0, log=True), 
        'batch_size': trial.suggest_categorical('batch_size', [64, 128, 256, 512]),
        'base_filters': trial.suggest_categorical('base_filters', [16, 32, 64, 128]),
        'growth': trial.suggest_float("growth", 1.0, 2.0),
        'use_bn': trial.suggest_categorical("use_bn", [True, False])
    }

    # crear vector con las configuraciones de las capas
    layers_config = []
    for i in range(3):
        filters = int(params['base_filters'] * (params['growth'] ** i))
        layers_config.append((filters, params['use_bn']))

    #actualizar el train loader con las nuevas configuraciones
    train_loader = DataLoader(
        train_dataset, 
        batch_size=params['batch_size'], 
        shuffle=True
    )

    model = CVAE(z_dim=params['z_dim'], layers_config=layers_config, device=device, cond_dim=2)
    
    optimizer = optim.Adam(model.parameters(), lr=params['lr'])

    num_epochs = 15
    
    # entrenamiento
    model.train()
    running_loss = 0.0
    
    for epoch in range(num_epochs):
        for data, y in train_loader:
            data = data.to(device).float()
            y = y.to(device).float()
            recon, mu_q, logvar_q, mu_p, logvar_p = model(data, y)
            
            loss, _, _ = loss_function(recon, data, mu_q, logvar_q, mu_p, logvar_p, params['beta'])
            
            # Si la pérdida es NaN, es una mala prueba. Devolver un valor alto.
            if torch.isnan(loss):
                return float('inf') 
            
            optimizer.zero_grad()
            loss.backward()
            
            # recorte de gradiente para que no exploten
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            
            optimizer.step()
            
            running_loss += loss.item() * data.size(0)

    # pérdida promedio por muestra
    avg_loss = running_loss / len(train_dataset)
    
    # Manejar el caso de que la pérdida final sea NaN
    if np.isnan(avg_loss):
        return float('inf')
        
    return avg_loss

# encontrar los mejores parametros
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=80)
print(f"mejores parametros: {study.best_params}")
# Out:
# [I 2025-11-17 16:51:59,498] A new study created in memory with name: no-name-5dd2cffb-eedf-49e1-a83b-fcdbe6a58e49
# [I 2025-11-17 16:57:00,579] Trial 0 finished with value: 575.7869239428476 and parameters: {'lr': 0.00016663201560192722, 'z_dim': 37, 'beta': 3.564452383518373, 'batch_size': 64, 'base_filters': 64, 'growth': 1.3265770607877885, 'use_bn': True}. Best is trial 0 with value: 575.7869239428476.
# [I 2025-11-17 16:58:27,072] Trial 1 finished with value: 328.37696496963935 and parameters: {'lr': 0.00012116281807201042, 'z_dim': 34, 'beta': 0.12474640580612183, 'batch_size': 256, 'base_filters': 32, 'growth': 1.059993575055837, 'use_bn': False}. Best is trial 1 with value: 328.37696496963935.
# [I 2025-11-17 17:03:39,662] Trial 2 finished with value: 711.8440320868302 and parameters: {'lr': 0.00022106160413785833, 'z_dim': 63, 'beta': 6.859758053005478, 'batch_size': 256, 'base_filters': 64, 'growth': 1.82504854024529, 'use_bn': True}. Best is trial 1 with value: 328.37696496963935.
# [I 2025-11-17 17:07:23,197] Trial 3 finished with value: 537475544374.1407 and parameters: {'lr': 0.005272065650800698, 'z_dim': 25, 'beta': 3.9577774498741585, 'batch_size': 512, 'base_filters': 64, 'growth': 1.4387502059481108, 'use_bn': False}. Best is trial 1 with value: 328.37696496963935.
# [I 2025-11-17 17:07:23,368] Trial 4 finished with value: inf and parameters: {'lr': 0.013123092780668309, 'z_dim': 24, 'beta': 0.48295450808559054, 'batch_size': 128, 'base_filters': 128, 'growth': 1.609615075188277, 'use_bn': True}. Best is trial 1 with value: 328.37696496963935.
# [I 2025-11-17 17:07:23,417] Trial 5 finished with value: inf and parameters: {'lr': 0.030244997917616496, 'z_dim': 56, 'beta': 0.5673847019858194, 'batch_size': 128, 'base_filters': 32, 'growth': 1.0882398066392351, 'use_bn': False}. Best is trial 1 with value: 328.37696496963935.
# [I 2025-11-17 17:08:43,488] Trial 6 finished with value: 132303224196.15321 and parameters: {'lr': 0.01432142579138583, 'z_dim': 14, 'beta': 0.3743120029459325, 'batch_size': 512, 'base_filters': 32, 'growth': 1.2727459917665604, 'use_bn': False}. Best is trial 1 with value: 328.37696496963935.
# [I 2025-11-17 17:19:46,047] Trial 7 finished with value: 480.56688305855596 and parameters: {'lr': 7.405133320221483e-05, 'z_dim': 36, 'beta': 1.6394150763699253, 'batch_size': 512, 'base_filters': 128, 'growth': 1.4952291257676444, 'use_bn': False}. Best is trial 1 with value: 328.37696496963935.
# [I 2025-11-17 17:21:43,444] Trial 8 finished with value: 476.16427624065 and parameters: {'lr': 0.00012790168502170508, 'z_dim': 50, 'beta': 1.6177313892765786, 'batch_size': 128, 'base_filters': 32, 'growth': 1.2476688768991373, 'use_bn': False}. Best is trial 1 with value: 328.37696496963935.
# [I 2025-11-17 17:21:43,498] Trial 9 finished with value: inf and parameters: {'lr': 0.030277893985807276, 'z_dim': 63, 'beta': 0.885963563127194, 'batch_size': 64, 'base_filters': 64, 'growth': 1.065021573623612, 'use_bn': False}. Best is trial 1 with value: 328.37696496963935.
# [I 2025-11-17 17:23:03,769] Trial 10 finished with value: 508.42441386373616 and parameters: {'lr': 1.992205743520328e-05, 'z_dim': 39, 'beta': 0.11263705198518408, 'batch_size': 256, 'base_filters': 16, 'growth': 1.9333968823773349, 'use_bn': True}. Best is trial 1 with value: 328.37696496963935.
# [I 2025-11-17 17:25:01,301] Trial 11 finished with value: 262.6416760996868 and parameters: {'lr': 0.0005121961729991779, 'z_dim': 50, 'beta': 0.12542175733067223, 'batch_size': 128, 'base_filters': 32, 'growth': 1.0048735448888317, 'use_bn': False}. Best is trial 11 with value: 262.6416760996868.
# [I 2025-11-17 17:26:20,241] Trial 12 finished with value: 253.5241442491105 and parameters: {'lr': 0.0013409922951712935, 'z_dim': 47, 'beta': 0.10928194870499953, 'batch_size': 256, 'base_filters': 32, 'growth': 1.0065073254981038, 'use_bn': False}. Best is trial 12 with value: 253.5241442491105.
# [I 2025-11-17 17:28:18,181] Trial 13 finished with value: 274.6827186077037 and parameters: {'lr': 0.001366801720686193, 'z_dim': 48, 'beta': 0.20584716322814697, 'batch_size': 128, 'base_filters': 32, 'growth': 1.1813369744377122, 'use_bn': False}. Best is trial 12 with value: 253.5241442491105.
# [I 2025-11-17 17:29:26,484] Trial 14 finished with value: 305.3287073919542 and parameters: {'lr': 0.000819739441122136, 'z_dim': 46, 'beta': 0.21270249152770063, 'batch_size': 256, 'base_filters': 16, 'growth': 1.0010586245223652, 'use_bn': False}. Best is trial 12 with value: 253.5241442491105.
# [I 2025-11-17 17:31:30,164] Trial 15 finished with value: 277.5496680705072 and parameters: {'lr': 0.0020179191809477975, 'z_dim': 54, 'beta': 0.23872310577231967, 'batch_size': 128, 'base_filters': 32, 'growth': 1.631690489531433, 'use_bn': False}. Best is trial 12 with value: 253.5241442491105.
# [I 2025-11-17 17:33:00,917] Trial 16 finished with value: 255.4190493589414 and parameters: {'lr': 0.0033264840672858646, 'z_dim': 44, 'beta': 0.13118253702932514, 'batch_size': 256, 'base_filters': 32, 'growth': 1.1749598339780603, 'use_bn': False}. Best is trial 12 with value: 253.5241442491105.
# [I 2025-11-17 17:34:30,252] Trial 17 finished with value: 296.47412437647455 and parameters: {'lr': 0.0031273849400725636, 'z_dim': 43, 'beta': 0.30159171719969646, 'batch_size': 256, 'base_filters': 32, 'growth': 1.1299004035391198, 'use_bn': False}. Best is trial 12 with value: 253.5241442491105.
# [I 2025-11-17 17:35:46,652] Trial 18 finished with value: 374.6945458476271 and parameters: {'lr': 0.006289123383046174, 'z_dim': 29, 'beta': 0.9143697530673942, 'batch_size': 256, 'base_filters': 16, 'growth': 1.3628683862943243, 'use_bn': True}. Best is trial 12 with value: 253.5241442491105.
# [I 2025-11-17 17:44:28,742] Trial 19 finished with value: 264.88228503685525 and parameters: {'lr': 0.0003824934395950863, 'z_dim': 16, 'beta': 0.10215026848012966, 'batch_size': 256, 'base_filters': 128, 'growth': 1.2002628965978044, 'use_bn': False}. Best is trial 12 with value: 253.5241442491105.
# [I 2025-11-17 17:46:19,316] Trial 20 finished with value: 275.7249615097133 and parameters: {'lr': 0.0012168131766363646, 'z_dim': 57, 'beta': 0.1980398929893349, 'batch_size': 256, 'base_filters': 32, 'growth': 1.6880329597461419, 'use_bn': False}. Best is trial 12 with value: 253.5241442491105.
# [I 2025-11-17 17:49:58,200] Trial 21 finished with value: 264.82516835906637 and parameters: {'lr': 0.0005394707276103495, 'z_dim': 51, 'beta': 0.15169090604000032, 'batch_size': 64, 'base_filters': 32, 'growth': 1.0193159786349302, 'use_bn': False}. Best is trial 12 with value: 253.5241442491105.
# [I 2025-11-17 17:51:56,524] Trial 22 finished with value: 260.8999978409371 and parameters: {'lr': 0.0028225799692328407, 'z_dim': 43, 'beta': 0.15383259506891464, 'batch_size': 128, 'base_filters': 32, 'growth': 1.165807527251507, 'use_bn': False}. Best is trial 12 with value: 253.5241442491105.
# [I 2025-11-17 17:53:26,263] Trial 23 finished with value: 302.2996855290121 and parameters: {'lr': 0.0035915422346585787, 'z_dim': 42, 'beta': 0.3298511177073388, 'batch_size': 256, 'base_filters': 32, 'growth': 1.1461907970634504, 'use_bn': False}. Best is trial 12 with value: 253.5241442491105.
# [I 2025-11-17 17:55:01,010] Trial 24 finished with value: 589.7659722916419 and parameters: {'lr': 0.010126774323732182, 'z_dim': 32, 'beta': 0.16545895852576328, 'batch_size': 256, 'base_filters': 32, 'growth': 1.414179675718131, 'use_bn': False}. Best is trial 12 with value: 253.5241442491105.
# [I 2025-11-17 17:56:59,105] Trial 25 finished with value: 327.96256472664606 and parameters: {'lr': 0.0018516324440847655, 'z_dim': 43, 'beta': 0.5715910731678485, 'batch_size': 128, 'base_filters': 32, 'growth': 1.24928824306074, 'use_bn': False}. Best is trial 12 with value: 253.5241442491105.
# [I 2025-11-17 18:01:07,513] Trial 26 finished with value: 295.8466341243865 and parameters: {'lr': 0.002616588114428932, 'z_dim': 40, 'beta': 0.26992186463542434, 'batch_size': 64, 'base_filters': 32, 'growth': 1.1279935240198675, 'use_bn': True}. Best is trial 12 with value: 253.5241442491105.
# [I 2025-11-17 18:01:08,207] Trial 27 finished with value: inf and parameters: {'lr': 0.0066397988020965755, 'z_dim': 46, 'beta': 0.1459781768538611, 'batch_size': 512, 'base_filters': 128, 'growth': 1.3217347922340106, 'use_bn': False}. Best is trial 12 with value: 253.5241442491105.
# [I 2025-11-17 18:02:17,885] Trial 28 finished with value: 285.8409512595262 and parameters: {'lr': 0.0010118414801893062, 'z_dim': 60, 'beta': 0.1725487448649537, 'batch_size': 256, 'base_filters': 16, 'growth': 1.2046733539762413, 'use_bn': False}. Best is trial 12 with value: 253.5241442491105.
# [I 2025-11-17 18:07:19,789] Trial 29 finished with value: 366.4279729732941 and parameters: {'lr': 4.7380706018554346e-05, 'z_dim': 30, 'beta': 0.41858847217607326, 'batch_size': 64, 'base_filters': 64, 'growth': 1.3272437937188102, 'use_bn': True}. Best is trial 12 with value: 253.5241442491105.
# [I 2025-11-17 18:09:18,548] Trial 30 finished with value: 266.3574613326959 and parameters: {'lr': 0.00028107645796234546, 'z_dim': 39, 'beta': 0.10151344763668053, 'batch_size': 128, 'base_filters': 32, 'growth': 1.0849371900477847, 'use_bn': False}. Best is trial 12 with value: 253.5241442491105.
# [I 2025-11-17 18:11:17,777] Trial 31 finished with value: 269.8600746510063 and parameters: {'lr': 0.0005701201129699166, 'z_dim': 52, 'beta': 0.15189177787660543, 'batch_size': 128, 'base_filters': 32, 'growth': 1.025932055664451, 'use_bn': False}. Best is trial 12 with value: 253.5241442491105.
# [I 2025-11-17 18:13:16,772] Trial 32 finished with value: 263.70083263873727 and parameters: {'lr': 0.0004434106856486687, 'z_dim': 47, 'beta': 0.12816606860283886, 'batch_size': 128, 'base_filters': 32, 'growth': 1.1049540751725873, 'use_bn': False}. Best is trial 12 with value: 253.5241442491105.
# [I 2025-11-17 18:15:16,043] Trial 33 finished with value: 254.7715912150531 and parameters: {'lr': 0.0040044881467699725, 'z_dim': 36, 'beta': 0.12583612921269785, 'batch_size': 128, 'base_filters': 32, 'growth': 1.0208754390768695, 'use_bn': False}. Best is trial 12 with value: 253.5241442491105.
# [I 2025-11-17 18:16:47,008] Trial 34 finished with value: 592.9460905910346 and parameters: {'lr': 0.004401699706750268, 'z_dim': 35, 'beta': 5.7114221560161225, 'batch_size': 256, 'base_filters': 32, 'growth': 1.173217969764679, 'use_bn': False}. Best is trial 12 with value: 253.5241442491105.
# [I 2025-11-17 18:16:47,078] Trial 35 finished with value: inf and parameters: {'lr': 0.01779635705706795, 'z_dim': 25, 'beta': 0.25027441804424033, 'batch_size': 128, 'base_filters': 64, 'growth': 1.0645771515260556, 'use_bn': False}. Best is trial 12 with value: 253.5241442491105.
# [I 2025-11-17 18:19:01,525] Trial 36 finished with value: 404.71222350663624 and parameters: {'lr': 0.007440813447935513, 'z_dim': 44, 'beta': 1.4281766345800768, 'batch_size': 128, 'base_filters': 32, 'growth': 1.2745345436076534, 'use_bn': True}. Best is trial 12 with value: 253.5241442491105.
# [I 2025-11-17 18:20:20,510] Trial 37 finished with value: 549.0358851959328 and parameters: {'lr': 0.0019917693971046074, 'z_dim': 8, 'beta': 2.217699055388595, 'batch_size': 512, 'base_filters': 32, 'growth': 1.0650001796205204, 'use_bn': False}. Best is trial 12 with value: 253.5241442491105.
# [I 2025-11-17 18:20:20,670] Trial 38 finished with value: inf and parameters: {'lr': 0.047072811297975255, 'z_dim': 37, 'beta': 0.5670209396536392, 'batch_size': 256, 'base_filters': 128, 'growth': 1.4972641600328809, 'use_bn': False}. Best is trial 12 with value: 253.5241442491105.
# [I 2025-11-17 18:22:20,952] Trial 39 finished with value: 272.9931772395829 and parameters: {'lr': 0.004373477673345611, 'z_dim': 28, 'beta': 0.1897613059539346, 'batch_size': 128, 'base_filters': 32, 'growth': 1.4082591349869438, 'use_bn': False}. Best is trial 12 with value: 253.5241442491105.
# [I 2025-11-17 18:22:21,176] Trial 40 finished with value: inf and parameters: {'lr': 0.011280121800804729, 'z_dim': 40, 'beta': 0.13439930966278904, 'batch_size': 512, 'base_filters': 64, 'growth': 1.7672406902213753, 'use_bn': True}. Best is trial 12 with value: 253.5241442491105.
# [I 2025-11-17 18:24:20,901] Trial 41 finished with value: 286.0157074460848 and parameters: {'lr': 0.00018528084920625546, 'z_dim': 49, 'beta': 0.12347017517968638, 'batch_size': 128, 'base_filters': 32, 'growth': 1.0031970307386056, 'use_bn': False}. Best is trial 12 with value: 253.5241442491105.
# [I 2025-11-17 18:26:19,781] Trial 42 finished with value: 259.673672484524 and parameters: {'lr': 0.0007973860534754187, 'z_dim': 34, 'beta': 0.11957875415848207, 'batch_size': 128, 'base_filters': 32, 'growth': 1.0446023373881006, 'use_bn': False}. Best is trial 12 with value: 253.5241442491105.
# [I 2025-11-17 18:28:18,145] Trial 43 finished with value: 249.52014966677103 and parameters: {'lr': 0.0013839035681656397, 'z_dim': 33, 'beta': 0.10147378127801751, 'batch_size': 128, 'base_filters': 32, 'growth': 1.1057255297154216, 'use_bn': False}. Best is trial 43 with value: 249.52014966677103.
# [I 2025-11-17 18:30:17,325] Trial 44 finished with value: 255.72444582911055 and parameters: {'lr': 0.000792571939052981, 'z_dim': 34, 'beta': 0.10896464952757043, 'batch_size': 128, 'base_filters': 32, 'growth': 1.111410253429771, 'use_bn': False}. Best is trial 43 with value: 249.52014966677103.
# [I 2025-11-17 18:32:16,119] Trial 45 finished with value: 251.83053940446842 and parameters: {'lr': 0.0012785360087901345, 'z_dim': 32, 'beta': 0.10507584368613397, 'batch_size': 128, 'base_filters': 32, 'growth': 1.1041482495957808, 'use_bn': False}. Best is trial 43 with value: 249.52014966677103.
# [I 2025-11-17 18:34:21,740] Trial 46 finished with value: 285.88861555308705 and parameters: {'lr': 0.0013408948678868724, 'z_dim': 22, 'beta': 0.22464303265728952, 'batch_size': 256, 'base_filters': 32, 'growth': 1.9847338214937276, 'use_bn': False}. Best is trial 43 with value: 249.52014966677103.
# [I 2025-11-17 18:36:21,286] Trial 47 finished with value: 650.0910748110865 and parameters: {'lr': 0.0002831487608811037, 'z_dim': 20, 'beta': 3.0896059721155194, 'batch_size': 128, 'base_filters': 16, 'growth': 1.2194499213496954, 'use_bn': False}. Best is trial 43 with value: 249.52014966677103.
# [I 2025-11-17 18:40:02,248] Trial 48 finished with value: 246.63029545947117 and parameters: {'lr': 0.0017518125263355487, 'z_dim': 32, 'beta': 0.10231673671634615, 'batch_size': 64, 'base_filters': 32, 'growth': 1.0805007477984054, 'use_bn': False}. Best is trial 48 with value: 246.63029545947117.
# [I 2025-11-17 18:48:57,462] Trial 49 finished with value: 263.3966078493778 and parameters: {'lr': 0.0017147222587749016, 'z_dim': 31, 'beta': 0.1762644576547866, 'batch_size': 64, 'base_filters': 128, 'growth': 1.1106711613399394, 'use_bn': False}. Best is trial 48 with value: 246.63029545947117.
# [I 2025-11-17 18:52:38,405] Trial 50 finished with value: 300.30386431081985 and parameters: {'lr': 0.0010920409308092685, 'z_dim': 27, 'beta': 0.3363403848215904, 'batch_size': 64, 'base_filters': 32, 'growth': 1.0743546553336414, 'use_bn': False}. Best is trial 48 with value: 246.63029545947117.
# [I 2025-11-17 18:56:20,581] Trial 51 finished with value: 246.43610289176505 and parameters: {'lr': 0.002402296401738324, 'z_dim': 32, 'beta': 0.10403485955895267, 'batch_size': 64, 'base_filters': 32, 'growth': 1.1447074053048156, 'use_bn': False}. Best is trial 51 with value: 246.43610289176505.
# [I 2025-11-17 19:00:02,249] Trial 52 finished with value: 249.76245331826289 and parameters: {'lr': 0.002497224576231622, 'z_dim': 27, 'beta': 0.10103088970944014, 'batch_size': 64, 'base_filters': 32, 'growth': 1.049478798669516, 'use_bn': False}. Best is trial 51 with value: 246.43610289176505.
# [I 2025-11-17 19:03:44,374] Trial 53 finished with value: 245.1236390306569 and parameters: {'lr': 0.002217898257668247, 'z_dim': 32, 'beta': 0.10021507869630727, 'batch_size': 64, 'base_filters': 32, 'growth': 1.1501004255795375, 'use_bn': False}. Best is trial 53 with value: 245.1236390306569.
# [I 2025-11-17 19:07:25,465] Trial 54 finished with value: 250.98604651221203 and parameters: {'lr': 0.0024717728785897102, 'z_dim': 27, 'beta': 0.10826168913958524, 'batch_size': 64, 'base_filters': 32, 'growth': 1.149017669455197, 'use_bn': False}. Best is trial 53 with value: 245.1236390306569.
# [I 2025-11-17 19:11:06,213] Trial 55 finished with value: 621.0931840919692 and parameters: {'lr': 0.0023299334397611257, 'z_dim': 23, 'beta': 8.10124120382952, 'batch_size': 64, 'base_filters': 32, 'growth': 1.2421038825867934, 'use_bn': False}. Best is trial 53 with value: 245.1236390306569.
# [I 2025-11-17 19:15:38,728] Trial 56 finished with value: 252.95153904099112 and parameters: {'lr': 0.005539915175229719, 'z_dim': 26, 'beta': 0.10123094432553742, 'batch_size': 64, 'base_filters': 64, 'growth': 1.289703791178049, 'use_bn': False}. Best is trial 53 with value: 245.1236390306569.
# [I 2025-11-17 19:19:50,389] Trial 57 finished with value: 97816409.2140659 and parameters: {'lr': 0.008229191424251424, 'z_dim': 20, 'beta': 0.1482676339314735, 'batch_size': 64, 'base_filters': 32, 'growth': 1.5464936371675435, 'use_bn': True}. Best is trial 53 with value: 245.1236390306569.
# [I 2025-11-17 19:23:31,319] Trial 58 finished with value: 279.6021996466384 and parameters: {'lr': 0.0015955542466768895, 'z_dim': 29, 'beta': 0.18329381822922794, 'batch_size': 64, 'base_filters': 16, 'growth': 1.1547976921086636, 'use_bn': False}. Best is trial 53 with value: 245.1236390306569.
# [I 2025-11-17 19:27:13,163] Trial 59 finished with value: 276.98830920667547 and parameters: {'lr': 0.0032983150354260653, 'z_dim': 33, 'beta': 0.2185925717491268, 'batch_size': 64, 'base_filters': 32, 'growth': 1.221349753878618, 'use_bn': False}. Best is trial 53 with value: 245.1236390306569.
# [I 2025-11-17 19:27:13,222] Trial 60 finished with value: inf and parameters: {'lr': 0.01612487899413724, 'z_dim': 37, 'beta': 0.10007593676351123, 'batch_size': 64, 'base_filters': 32, 'growth': 1.1465944574057885, 'use_bn': False}. Best is trial 53 with value: 245.1236390306569.
# [I 2025-11-17 19:30:53,268] Trial 61 finished with value: 252.22612119405937 and parameters: {'lr': 0.0023001757536179656, 'z_dim': 31, 'beta': 0.11935996803518985, 'batch_size': 64, 'base_filters': 32, 'growth': 1.0905530798683214, 'use_bn': False}. Best is trial 53 with value: 245.1236390306569.
# [I 2025-11-17 19:34:32,449] Trial 62 finished with value: 428.30512532636874 and parameters: {'lr': 1.014575946290525e-05, 'z_dim': 27, 'beta': 0.13824366270439947, 'batch_size': 64, 'base_filters': 32, 'growth': 1.0502601174609898, 'use_bn': False}. Best is trial 53 with value: 245.1236390306569.
# [I 2025-11-17 19:38:12,680] Trial 63 finished with value: 253.15202356712945 and parameters: {'lr': 0.0009826273911805765, 'z_dim': 33, 'beta': 0.11843222205139894, 'batch_size': 64, 'base_filters': 32, 'growth': 1.1878588951154627, 'use_bn': False}. Best is trial 53 with value: 245.1236390306569.
# [I 2025-11-17 19:41:52,935] Trial 64 finished with value: 268.8993204310213 and parameters: {'lr': 0.0006784228551781121, 'z_dim': 30, 'beta': 0.1608693662715503, 'batch_size': 64, 'base_filters': 32, 'growth': 1.1329677323297487, 'use_bn': False}. Best is trial 53 with value: 245.1236390306569.
# [I 2025-11-17 19:45:32,738] Trial 65 finished with value: 252.47118435478052 and parameters: {'lr': 0.0015007023966450057, 'z_dim': 24, 'beta': 0.10078892876070372, 'batch_size': 64, 'base_filters': 32, 'growth': 1.1018059815446346, 'use_bn': False}. Best is trial 53 with value: 245.1236390306569.
# [I 2025-11-17 19:49:12,106] Trial 66 finished with value: 258.4482108665618 and parameters: {'lr': 0.0027259656688541495, 'z_dim': 32, 'beta': 0.1414038996422037, 'batch_size': 64, 'base_filters': 32, 'growth': 1.0409980895629916, 'use_bn': False}. Best is trial 53 with value: 245.1236390306569.
# [I 2025-11-17 19:58:22,141] Trial 67 finished with value: 251.6940570647054 and parameters: {'lr': 0.0010875060544964198, 'z_dim': 21, 'beta': 0.11519661947045276, 'batch_size': 64, 'base_filters': 128, 'growth': 1.1799109184295933, 'use_bn': False}. Best is trial 53 with value: 245.1236390306569.
# [I 2025-11-17 20:08:42,820] Trial 68 finished with value: 438412.0318560011 and parameters: {'lr': 0.005167718840393302, 'z_dim': 15, 'beta': 0.26697559623791156, 'batch_size': 64, 'base_filters': 128, 'growth': 1.2500910392414077, 'use_bn': True}. Best is trial 53 with value: 245.1236390306569.
# [I 2025-11-17 20:17:52,881] Trial 69 finished with value: 271.8865525526535 and parameters: {'lr': 0.0019348503603121834, 'z_dim': 19, 'beta': 0.19067038876833278, 'batch_size': 64, 'base_filters': 128, 'growth': 1.1905946808007801, 'use_bn': False}. Best is trial 53 with value: 245.1236390306569.
# [I 2025-11-17 20:27:45,792] Trial 70 finished with value: 267.9293049182414 and parameters: {'lr': 0.0006541205260550217, 'z_dim': 17, 'beta': 0.16755493975448701, 'batch_size': 64, 'base_filters': 128, 'growth': 1.3486006472783971, 'use_bn': False}. Best is trial 53 with value: 245.1236390306569.
# [I 2025-11-17 20:36:54,378] Trial 71 finished with value: 251.6762075471526 and parameters: {'lr': 0.0010340721467046628, 'z_dim': 22, 'beta': 0.11620215907061918, 'batch_size': 64, 'base_filters': 128, 'growth': 1.1362768273451986, 'use_bn': False}. Best is trial 53 with value: 245.1236390306569.
# [I 2025-11-17 20:45:56,453] Trial 72 finished with value: 251.8180700043252 and parameters: {'lr': 0.0009767167521520907, 'z_dim': 21, 'beta': 0.11426794924304133, 'batch_size': 64, 'base_filters': 128, 'growth': 1.1516931081790833, 'use_bn': False}. Best is trial 53 with value: 245.1236390306569.
# [I 2025-11-17 20:55:04,641] Trial 73 finished with value: 260.02382413369475 and parameters: {'lr': 0.002943936664335889, 'z_dim': 24, 'beta': 0.1358210653285096, 'batch_size': 64, 'base_filters': 128, 'growth': 1.136587961357685, 'use_bn': False}. Best is trial 53 with value: 245.1236390306569.
# [I 2025-11-17 21:03:47,471] Trial 74 finished with value: 263.45681239387494 and parameters: {'lr': 0.0004183010555866215, 'z_dim': 13, 'beta': 0.11664427327647862, 'batch_size': 64, 'base_filters': 128, 'growth': 1.0753604341862715, 'use_bn': False}. Best is trial 53 with value: 245.1236390306569.
# [I 2025-11-17 21:12:54,385] Trial 75 finished with value: 261.44554165728863 and parameters: {'lr': 0.0022329297521311645, 'z_dim': 26, 'beta': 0.15621182043993967, 'batch_size': 64, 'base_filters': 128, 'growth': 1.170419238387637, 'use_bn': False}. Best is trial 53 with value: 245.1236390306569.
# [I 2025-11-17 21:23:07,048] Trial 76 finished with value: 255.27859889227406 and parameters: {'lr': 0.0016069327481091648, 'z_dim': 28, 'beta': 0.1381476078866533, 'batch_size': 64, 'base_filters': 128, 'growth': 1.297127786115514, 'use_bn': False}. Best is trial 53 with value: 245.1236390306569.
# [I 2025-11-17 21:23:54,990] Trial 77 finished with value: 271.39325342090507 and parameters: {'lr': 0.0037183363819978258, 'z_dim': 29, 'beta': 0.115361126942828, 'batch_size': 512, 'base_filters': 16, 'growth': 1.2162100383577614, 'use_bn': False}. Best is trial 53 with value: 245.1236390306569.
# [I 2025-11-17 21:32:27,523] Trial 78 finished with value: 339.82034310129416 and parameters: {'lr': 0.001120844580656156, 'z_dim': 18, 'beta': 0.7965882717720865, 'batch_size': 64, 'base_filters': 128, 'growth': 1.0363742491861718, 'use_bn': False}. Best is trial 53 with value: 245.1236390306569.
# [I 2025-11-17 21:36:40,682] Trial 79 finished with value: 274.16002784453724 and parameters: {'lr': 0.0009185591001257212, 'z_dim': 22, 'beta': 0.2007839887858959, 'batch_size': 64, 'base_filters': 64, 'growth': 1.1242518862796107, 'use_bn': False}. Best is trial 53 with value: 245.1236390306569.
# mejores parametros: {'lr': 0.002217898257668247, 'z_dim': 32, 'beta': 0.10021507869630727, 'batch_size': 64, 'base_filters': 32, 'growth': 1.1501004255795375, 'use_bn': False}

# %% [markdown]
# Se grafica la importancia/sensiblidad de cada hiperparámetro en el modelo

# %%
# importancia 
fig = vis.plot_param_importances(study)
fig.show()
# Out:
# [W 2025-11-17 21:36:40,733] Trial 4 is omitted in visualization because its objective value is inf or nan.
# [W 2025-11-17 21:36:40,734] Trial 5 is omitted in visualization because its objective value is inf or nan.
# [W 2025-11-17 21:36:40,734] Trial 9 is omitted in visualization because its objective value is inf or nan.
# [W 2025-11-17 21:36:40,735] Trial 27 is omitted in visualization because its objective value is inf or nan.
# [W 2025-11-17 21:36:40,735] Trial 35 is omitted in visualization because its objective value is inf or nan.
# [W 2025-11-17 21:36:40,736] Trial 38 is omitted in visualization because its objective value is inf or nan.
# [W 2025-11-17 21:36:40,737] Trial 40 is omitted in visualization because its objective value is inf or nan.
# [W 2025-11-17 21:36:40,737] Trial 60 is omitted in visualization because its objective value is inf or nan.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="498fb743-da7f-40bc-8e98-fba87bbe8287" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("498fb743-da7f-40bc-8e98-fba87bbe8287")) {                    Plotly.newPlot(                        "498fb743-da7f-40bc-8e98-fba87bbe8287",                        [{"cliponaxis":false,"hovertemplate":["use_bn (CategoricalDistribution): 0.031064249037422605\u003cextra\u003e\u003c\u002fextra\u003e","growth (FloatDistribution): 0.03876394015976538\u003cextra\u003e\u003c\u002fextra\u003e","base_filters (CategoricalDistribution): 0.055649041158993884\u003cextra\u003e\u003c\u002fextra\u003e","z_dim (IntDistribution): 0.0635886980940901\u003cextra\u003e\u003c\u002fextra\u003e","beta (FloatDistribution): 0.1737839598766008\u003cextra\u003e\u003c\u002fextra\u003e","batch_size (CategoricalDistribution): 0.19618146364771902\u003cextra\u003e\u003c\u002fextra\u003e","lr (FloatDistribution): 0.4409686480254084\u003cextra\u003e\u003c\u002fextra\u003e"],"name":"Objective Value","orientation":"h","text":["0.03","0.04","0.06","0.06","0.17","0.20","0.44"],"textposition":"outside","x":[0.031064249037422605,0.03876394015976538,0.055649041158993884,0.0635886980940901,0.1737839598766008,0.19618146364771902,0.4409686480254084],"y":["use_bn","growth","base_filters","z_dim","beta","batch_size","lr"],"type":"bar"}],                        {"title":{"text":"Hyperparameter Importances"},"xaxis":{"title":{"text":"Hyperparameter Importance"}},"yaxis":{"title":{"text":"Hyperparameter"}},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.333333 ...

# %%
class EarlyStopping:
    def __init__(self, patience=5, min_delta=0.0):
        self.patience = patience
        self.min_delta = min_delta
        self.best_loss = float('inf')
        self.counter = 0

    def step(self, current_loss):
        if current_loss < self.best_loss - self.min_delta:
            self.best_loss = current_loss
            self.counter = 0
        else:
            self.counter += 1
        return self.counter >= self.patience

# %% [markdown]
# El entrenamiento se realiza con los mejores parámetros encontrados por bayes

# %%
best_params = study.best_params

num_epochs = 25
z_dim = best_params['z_dim'] 
beta = best_params['beta']
num_layers = 3
base_filters = best_params['base_filters']
growth = best_params['growth']
use_bn = best_params['use_bn']

layers_config = []

for i in range(num_layers):
        filters = int(base_filters * (growth ** i))
        layers_config.append((filters, use_bn))


model = CVAE(z_dim=z_dim, layers_config=layers_config, device=device, cond_dim=2)

optimizer = optim.Adam(model.parameters(), lr=best_params['lr'])

train_loader = DataLoader(
    dataset=train_dataset, 
    batch_size=best_params['batch_size'] , 
    shuffle=True
)
epoch_loss_history = {'total': [], 'mse': [], 'kld': [], 'val_mse': []}

early_stopper = EarlyStopping(patience=5, min_delta=1e-3)
for epoch in range(num_epochs):
    model.train() 
    running_loss = 0.0
    running_mse = 0.0 # Acumulador para mse
    running_kld = 0.0 # Acumulador para KLD
    
    for batch_idx, (data, y) in enumerate(train_loader):
        data = data.to(device) 
        y = y.to(device)
        # propagacion
        recon_batch, mu_q, logvar_q, mu_p, logvar_p = model(data, y)
        
        # perdida 
        loss, mse_sum, kld_sum = loss_function(recon_batch, data, mu_q, logvar_q, mu_p, logvar_p, beta)
        
        # backpropagation y opt
        optimizer.zero_grad() # Limpia gradientes
        loss.backward()       # Calcula gradientes
        optimizer.step()      # Actualiza pesos

        # Acumula la pérdida
        running_loss += loss.item() * data.size(0) 
        running_mse += mse_sum.item() # Acumular BCE total
        running_kld += kld_sum.item() # Acumular KLD total
    
    # Calcular promedios por época
    avg_loss = running_loss / len(train_dataset)
    avg_mse = running_mse / len(train_dataset)
    avg_kld = running_kld / len(train_dataset)
    
    # Guardar promedios de la época
    epoch_loss_history['total'].append(avg_loss)
    epoch_loss_history['mse'].append(avg_mse)
    epoch_loss_history['kld'].append(avg_kld)

    #validacion
    model.eval()
    running_val_mse = 0.0
    with torch.no_grad():
        for val_data, val_y in val_loader:
            val_data = val_data.to(device)
            val_y = val_y.to(device).float()
            
            # generar imagen desde la condicion y, aplicando el prior p(z|y)
            mu_p, logvar_p = model.get_prior(val_y)
            z_sample = model.reparameterize(mu_p, logvar_p) # Muestra del prior
            recon_batch = model.decode(z_sample, val_y)
            
            # Calcular MSE
            val_mse = F.mse_loss(recon_batch, val_data, reduction='sum')
            running_val_mse += val_mse.item()

    avg_val_mse = running_val_mse / len(val_dataset)
    epoch_loss_history['val_mse'].append(avg_val_mse)
    
    if early_stopper.step(avg_loss):
        print(f"Early stopping activado en la época {epoch+1}")
        break

    # Reporte de la época 
    print(f"Epoch [{epoch+1}/{num_epochs}], Pérdida Total: {avg_loss:.4f}, MSE: {avg_mse:.4f}, KLD: {avg_kld:.4f}")

print("finish.")
# Out:
# Epoch [1/25], Pérdida Total: 19.6051, MSE: 16.8253, KLD: 27.7385
# Epoch [2/25], Pérdida Total: 16.9241, MSE: 14.4527, KLD: 24.6610
# Epoch [3/25], Pérdida Total: 16.5750, MSE: 14.1853, KLD: 23.8455
# Epoch [4/25], Pérdida Total: 16.3842, MSE: 14.0291, KLD: 23.5011
# Epoch [5/25], Pérdida Total: 16.2542, MSE: 13.9339, KLD: 23.1537
# Epoch [6/25], Pérdida Total: 16.1713, MSE: 13.8695, KLD: 22.9685
# Epoch [7/25], Pérdida Total: 16.1086, MSE: 13.8236, KLD: 22.8012
# Epoch [8/25], Pérdida Total: 16.0604, MSE: 13.7874, KLD: 22.6810
# Epoch [9/25], Pérdida Total: 16.0178, MSE: 13.7569, KLD: 22.5606
# Epoch [10/25], Pérdida Total: 15.9844, MSE: 13.7310, KLD: 22.4857
# Epoch [11/25], Pérdida Total: 15.9547, MSE: 13.7102, KLD: 22.3966
# Epoch [12/25], Pérdida Total: 15.9327, MSE: 13.6930, KLD: 22.3489
# Epoch [13/25], Pérdida Total: 15.9126, MSE: 13.6767, KLD: 22.3114
# Epoch [14/25], Pérdida Total: 15.8871, MSE: 13.6585, KLD: 22.2389
# Epoch [15/25], Pérdida Total: 15.8741, MSE: 13.6498, KLD: 22.1957
# Epoch [16/25], Pérdida Total: 15.8556, MSE: 13.6354, KLD: 22.1537
# Epoch [17/25], Pérdida Total: 15.8416, MSE: 13.6244, KLD: 22.1241
# Epoch [18/25], Pérdida Total: 15.8282, MSE: 13.6140, KLD: 22.0949
# Epoch [19/25], Pérdida Total: 15.8155, MSE: 13.6057, KLD: 22.0507
# Epoch [20/25], Pérdida Total: 15.8060, MSE: 13.5965, KLD: 22.0478
# Epoch [21/25], Pérdida Total: 15.7988, MSE: 13.5906, KLD: 22.0346
# Epoch [22/25], Pérdida Total: 15.7863, MSE: 13.5816, KLD: 21.9997
# Epoch [23/25], Pérdida Total: 15.7727, MSE: 13.5718, KLD: 21.9609
# Epoch [24/25], Pérdida Total: 15.7685, MSE: 13.5649, KLD: 21.9883
# Epoch [25/25], Pérdida Total: 15.7549, MSE: 13.5583, KLD: 21.9190
# finish.

# %%
MODEL_PATH = '/kaggle/working/vae_spines_pesos_final.pth'

torch.save(model.state_dict(), MODEL_PATH)

print(f"pesos guardados en: {MODEL_PATH}")
# Out:
# pesos guardados en: /kaggle/working/vae_spines_pesos_final.pth

# %% [markdown]
# se grafica la función de pérdida, en este caso se añade la pérdida por validación ya que pasó a ser un modelo condicionado entonces se puede evaluar con una validación

# %%
def plot_epoch_loss_history(history):
    plt.figure(figsize=(12, 6))
    
    epochs = range(1, len(history['total']) + 1)
    
    plt.plot(epochs, history['total'], label='Pérdida total (Train)', color='blue', marker='o')
    plt.plot(epochs, history['mse'], label='Reconstrucción MSE (Train)', color='red', linestyle='--', marker='s')
    plt.plot(epochs, history['kld'], label='Divergencia KL (Train)', color='green', linestyle='--', marker='x')
    plt.plot(epochs, history['val_mse'], label='Validación MSE (Val)', color='purple', linestyle=':', marker='d')
    
    # Etiquetas y Título
    plt.title('Pérdidas del CVAE durante el Entrenamiento', fontsize=16)
    plt.xlabel('Época')
    plt.ylabel('Pérdida Promediada por Muestra')
    plt.xticks(epochs) 
    plt.legend()
    plt.grid(True, alpha=0.5)
    plt.show()

plot_epoch_loss_history(epoch_loss_history)

# %% [markdown]
# Estimar imagenes y compararlas con las originales

# %%
model.eval()

data_val, y_val = next(iter(val_loader))
data_val = data_val.to(device)
y_val = y_val.to(device)

with torch.no_grad():
    # El modelo calcula tanto la reconstrucción como el prior.
    # Solo interesa el mu_p y log_p para la estimación
    _, _, _, mu_p, log_p = model(data_val, y_val)
    
    # Generación desde el prior (x_gen)
    z_prior = model.reparameterize(mu_p, log_p)
    gen_val = model.decode(z_prior, y_val)

# Mover a CPU para plotear
data_val = data_val.cpu()
gen_val = gen_val.cpu()

# Número de ejemplos a plotear
n = 8 

plt.figure(figsize=(n * 2.5, 5)) 

for i in range(n):
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(data_val[i, 0], cmap='jet')
    ax.set_title(f"KDM={y_val[i,0]:.2f}\nT={y_val[i,1]:.2f}", fontsize=10)
    if i == 0:
        ax.set_ylabel("Original", fontsize=12, weight='bold')
    ax.axis('off')
    ax = plt.subplot(2, n, i + n + 1)
    plt.imshow(gen_val[i, 0], cmap='jet')
    if i == 0:
        ax.set_ylabel("Generada", fontsize=12, weight='bold')
    ax.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# visualización del espacio latente con umap.
# se visualiza el espacio latente después de cada capa y en el espacio latente final se superponen las imagenes estimadas

# %%
model.eval()

# Diccionarios y listas para almacenar todos los datos
all_features = {'L1': [], 'L2': [], 'L3': []}
all_z = []
all_T = []
all_KDM = []
all_gen_images = [] 

with torch.no_grad():
    for data_batch, y_batch in val_loader:
        data_batch = data_batch.to(device)
        y_batch = y_batch.to(device)

        # 1. Extraer features intermedios (L1, L2, L3)
        intermediate_features = model.get_intermediate_features(data_batch)
        for key in all_features:
            all_features[key].append(intermediate_features[key].cpu().numpy())
            
        # 2. Extraer espacio latente (media mu_q)
        mu_q, _ = model.encode(data_batch, y_batch)
        all_z.append(mu_q.cpu().numpy())

        # 3. NUEVO: Generar imágenes desde mu_q (para la Celda 29)
        #    Esto reemplaza la lógica de la Celda 28
        gen_batch = model.decode(mu_q, y_batch)
        all_gen_images.append(gen_batch.cpu().numpy())

        # 4. Extraer etiquetas
        all_KDM.append(y_batch[:, 0].cpu().numpy()) 
        all_T.append(y_batch[:, 1].cpu().numpy())     

# Concatenar todos los batches
print("Concatenando batches...")
for key in all_features:
    all_features[key] = np.concatenate(all_features[key], axis=0)

all_z = np.concatenate(all_z, axis=0)
all_T = np.concatenate(all_T, axis=0)
all_KDM = np.concatenate(all_KDM, axis=0)
all_gen_images = np.concatenate(all_gen_images, axis=0)

n_total_samples = all_z.shape[0]
n_samples_for_umap = 10000 # Muestras a usar para UMAP 

if n_samples_for_umap > n_total_samples:
    n_samples_for_umap = n_total_samples

# Crear índices aleatorios para el subconjunto
np.random.seed(42) # Para reproducibilidad
subset_indices = np.random.choice(n_total_samples, n_samples_for_umap, replace=False)

# Aplicar el subconjunto a todos los datos
all_z_sub = all_z[subset_indices]
all_T_sub = all_T[subset_indices]
all_KDM_sub = all_KDM[subset_indices]
all_gen_images_sub = all_gen_images[subset_indices]

all_features_sub = {}
for key in all_features:
    all_features_sub[key] = all_features[key][subset_indices]
    
umap_results = {}
layers = ['L1', 'L2', 'L3']
all_spaces = layers + ['Z']

for space in all_spaces:
    if space == 'Z':
        data_to_map = all_z_sub
    else:
        data_to_map = all_features_sub[space]

    # Mover solo el subconjunto a la GPU 
    data_cp = cp.asarray(data_to_map) 
    
    reducer = cumlUMAP(n_neighbors=15, min_dist=0.1, n_components=2, random_state=42)
    umap_coords_cp = reducer.fit_transform(data_cp)
    umap_results[space] = cp.asnumpy(umap_coords_cp)
    del data_cp # Limpiar memoria de GPU

all_T = all_T_sub
all_KDM = all_KDM_sub
gen_images_for_umap = all_gen_images_sub
# Out:
# Concatenando batches...
# [2025-11-17 21:43:04.985] [CUML] [info] build_algo set to brute_force_knn because random_state is given
# [2025-11-17 21:43:09.356] [CUML] [info] build_algo set to brute_force_knn because random_state is given
# [2025-11-17 21:43:12.754] [CUML] [info] build_algo set to brute_force_knn because random_state is given
# [2025-11-17 21:43:13.663] [CUML] [info] build_algo set to brute_force_knn because random_state is given

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 12))
layers = ['L1', 'L2', 'L3']
color_data = [all_T, all_KDM]
color_labels = ['T', 'KDM']

for row, (c_data, c_label) in enumerate(zip(color_data, color_labels)):
    
    for col, layer in enumerate(layers):
        ax = axes[row, col]
        coords = umap_results[layer]
        
        scatter = ax.scatter(coords[:, 0], coords[:, 1], c=c_data, cmap='jet', s=10, alpha=0.6)
        
        ax.set_title(f"{layer} coloreado por {c_label}", fontsize=14)
        ax.set_xlabel("Dim 1")
        ax.set_ylabel("Dim 2")
        fig.colorbar(scatter, ax=ax, label=c_label)

plt.suptitle("umap sobre las capas convolucionales", fontsize=18, y=1.02)
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 9))

coords_z = umap_results['Z']
color_data_z = [all_T, all_KDM]

# coloreado por t
ax_T = axes[0]
scatter_T = ax_T.scatter(coords_z[:, 0], coords_z[:, 1], c=color_data[0], cmap='jet', s=10, alpha=0.3) 
ax_T.set_title("Espacio Latente Z (mu_q) coloreado por T", fontsize=14)
ax_T.set_xlabel("Dim 1")
ax_T.set_ylabel("Dim 2")
ax_T.grid(True, alpha=0.2) 

# coloreado por kdm
ax_KDM = axes[1]
scatter_KDM = ax_KDM.scatter(coords_z[:, 0], coords_z[:, 1], c=color_data[1], cmap='jet', s=10, alpha=0.3) # Reducimos alfa
ax_KDM.set_title("Espacio Latente Z (mu_q) coloreado por KDM", fontsize=14)
ax_KDM.set_xlabel("Dim 1")
ax_KDM.set_ylabel("Dim 2")
ax_KDM.grid(True, alpha=0.2) 

# subconjunto de img a superponer
n_images_to_plot = 150 
if n_images_to_plot > len(coords_z):
    n_images_to_plot = len(coords_z)

indices = np.random.choice(range(len(coords_z)), n_images_to_plot, replace=False)

for i in indices:
    img_np = gen_images_for_umap[i].transpose(1, 2, 0)
    img_np = (img_np - img_np.min()) / (img_np.max() - img_np.min())
    imagebox = OffsetImage(img_np, zoom=0.5, cmap='jet') 
    x_coord = coords_z[i, 0]
    y_coord = coords_z[i, 1]
    ab_T = AnnotationBbox(imagebox, (x_coord, y_coord), frameon=False, pad=0.0)
    ax_T.add_artist(ab_T)
    ab_KDM = AnnotationBbox(imagebox, (x_coord, y_coord), frameon=False, pad=0.0)
    ax_KDM.add_artist(ab_KDM)

plt.suptitle("Espacio latente final Z", fontsize=16, y=1.02)
plt.tight_layout()
plt.show()
